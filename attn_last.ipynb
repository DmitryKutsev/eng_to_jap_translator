# %% [markdown]
# <a href="https://colab.research.google.com/github/DmitryKutsev/eng_to_jap_translator/blob/main/attn_last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tinysegmenter
# Out:
# Collecting tinysegmenter
#   Downloading https://files.pythonhosted.org/packages/9c/70/488895cb11e160b548c9ba5847c171b65b86a8ca1e54d206d55b2976bf7b/tinysegmenter-0.4.tar.gz
# Building wheels for collected packages: tinysegmenter
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.4-cp36-none-any.whl size=13536 sha256=9863aaac13486f02615a437b961ebc1cce2d65c2d17df22d6d9d57d56067279e
#   Stored in directory: /root/.cache/pip/wheels/68/71/2b/6402196bf28012826e507ef7b99df6ebd98cce78bd99023471
# Successfully built tinysegmenter
# Installing collected packages: tinysegmenter
# Successfully installed tinysegmenter-0.4

# %% [markdown]
# *Kurohashi-Kawahara Lab. has the copyright of Japanese Basic Sentence Data, and NICT MASTAR Project, Multilingual Translation Lab. has the copyright of English and Chinese Basic Sentence Data. You can use all the data under the terms of the Creative Commons Attribution 3.0 Unported license.
#      http://nlp.ist.i.kyoto-u.ac.jp/EN/?JEC%20Basic%20Sentence%20Data*

# %%
import math
import numpy as np
import pandas as pd
import random
import json
import torch
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from matplotlib import pyplot as plt
from math import ceil
from nltk.translate.bleu_score import corpus_bleu

from io import open
import unicodedata
import string
import re
import random
import spacy
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd
import tinysegmenter

# %%
spacy_en = spacy.load('en')

# %%
segmenter = tinysegmenter.TinySegmenter()

# %%
device = torch.device('cuda:0')

# %%
my_frame = pd.read_excel('http://nlp.ist.i.kyoto-u.ac.jp/EN/?plugin=attach&refer=JEC%20Basic%20Sentence%20Data&openfile=JEC_basic_sentence_v1-2.xls')

# %%
#remove Chineese column
my_frame = my_frame.drop(['难道不会是X吗，我实在是感到怀疑。'], axis=1)
my_frame.columns = ['index', 'jp', 'en']
my_frame = my_frame.drop(['index'], axis=1)

# %%
my_frame
# Out:
#                          jp                                                 en
# 0             Xがいいなといつも思います                    I always think X would be nice.
# 1           それがあるようにいつも思います                  It always seems like it is there.
# 2            それが多すぎないかと正直思う            I honestly feel like there is too much.
# 3      山田はみんなに好かれるタイプの人だと思う   I think that Yamada is the type everybody likes.
# 4                  〜と誰かが思った                             Someone thought that 〜
# ...                     ...                                                ...
# 5298   チームが４人のメンバーで構成されています                 The team consists of four members.
# 5299           彼が実際に動画を再生する                       He actually plays the video.
# 5300  政府が銀行に公的資金をどんどん投入しました  The government injected massive public funds i...
# 5301    レベル１の機能に下記の機能をプラスする  The following will be added to the level 1 fun...
# 5302       彼が携帯を制服のポケットに仕舞う  He puts his cell phone into the pocket of his ...
#
# [5303 rows x 2 columns]

# %%
segmenter.tokenize(my_frame['jp'][0])
# Out:
# ['X', 'が', 'いい', 'な', 'といつも', '思い', 'ます']

# %%
[tok.text for tok in spacy_en.tokenizer(my_frame['en'][1])]
# Out:
# ['It', 'always', 'seems', 'like', 'it', 'is', 'there', '.']

# %%
for word in spacy_en.tokenizer(my_frame['en'][1]):
  print(word)
# Out:
# It
# always
# seems
# like
# it
# is
# there
# .

# %%
valid_border = ceil(len(my_frame)*0.8)

# %%
train_df = my_frame[:valid_border]
valid_df = my_frame[valid_border:]
len(train_df), len(valid_df)
valid_df = valid_df.reset_index()

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters


# def normalizeString(s):
#     # s = unicodeToAscii(s.lower().strip())
#     s = re.sub(r"([.!?])", r" \1", s)
#     s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
#     return s

# %%
    for index, sent in enumerate(train_df['jp']):
      if index == 1:
        print(index, sent)
      pair = [str(spacy_en.tokenizer(train_df['en'][index].lower())), ' '.join(segmenter.tokenize(sent))]
      if index == 1:
        print(pair)
# Out:
# 1 それがあるようにいつも思います
# ['it always seems like it is there.', 'それ が ある よう にいつも 思い ます']

# %%
def readLangs(lang1, lang2, frame, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    # lines = open('data/%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
    #     read().strip().split('\n')
    pairs = []
    # Split every line into pairs and normalize
    for index, sent in enumerate(frame['jp']):
      pair = [str(spacy_en.tokenizer(frame['en'][index].lower())), ' '.join(segmenter.tokenize(sent))]
      pairs.append(pair)

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
MAX_LENGTH = 20


def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH
        # p[0].startswith(eng_prefixes)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
def prepareData(lang1, lang2, frame, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, frame, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


input_lang, output_lang, pairs = prepareData('en', 'jp', my_frame, False)
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 5303 sentence pairs
# Trimmed to 5220 sentence pairs
# Counting words...
# Counted words:
# en 7329
# jp 6988
# ['cut the camembert cheese and the vegetables into the desired size.', 'カマンベールチーズ と 野菜 を 好み の 大きさ に 切る']

# %%
_, _, train_pairs = prepareData('en', 'jp', train_df, False)
print(random.choice(train_pairs))
# Out:
# Reading lines...
# Read 4243 sentence pairs
# Trimmed to 4182 sentence pairs
# Counting words...
# Counted words:
# en 6237
# jp 5656
# ['i recommend x.', '私 は X を お勧めい た し ます']

# %%
_, _, valid_pairs = prepareData('en', 'jp', valid_df, False)
print(random.choice(train_pairs))
# Out:
# Reading lines...
# Read 1060 sentence pairs
# Trimmed to 1038 sentence pairs
# Counting words...
# Counted words:
# en 2827
# jp 2820
# ["let's find a good real estate agent around kyoto.", '京都 近辺 で お気 に 入り の 不動産 会社 を 見付け ましょ う']

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, 
          decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
try:
  for instance in list(tqdm._instances):
    tqdm._decr_instances(instance)
except Exception as e:
  pass

# %%
def trainIters(encoder, decoder, epochs, print_every=500, 
               plot_every=100, learning_rate=0.01):
    start = time.time()
    # plot_losses = []
    list_losses = []
    loss_total = 0
      # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    local_pairs = [tensorsFromPair(pair)
                      for pair in train_pairs]
    criterion = nn.NLLLoss()

    
    for e in range(epochs):
      progress_bar = tqdm(total=epochs, desc=f'{ e }')
      for iter in range(len(local_pairs) - 1):

          training_pair = local_pairs[iter]
          input_tensor = training_pair[0]
          target_tensor = training_pair[1]

          loss = train(input_tensor, target_tensor, encoder,
                      decoder, encoder_optimizer, decoder_optimizer, criterion)
          loss_total += loss
          plot_loss_total += loss
          list_losses.append(loss)
          # if iter % print_every == 0:
          #     print_loss_avg = print_loss_total / print_every
          #     print_loss_total = 0
          #     print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
          #                                 iter, iter / n_iters * 100, print_loss_avg))

          # if iter % plot_every == 0:
          #     plot_loss_avg = plot_loss_total / plot_every
          #     plot_losses.append(plot_loss_avg)
          #     plot_loss_total = 0

          progress_bar.set_postfix(loss=np.mean(list_losses[-print_every:]),
                                  perplexity=np.exp(np.mean(list_losses[-print_every:])))
          progress_bar.update()
      
      progress_bar.close()

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %%
hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

# %%
hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

trainIters(encoder1, attn_decoder1, 2)
# Out:
# 0:   0%|          | 0/2 [00:00<?, ?it/s]
#
#
#
#
# 0:   0%|          | 0/2 [00:00<?, ?it/s, loss=8.85, perplexity=6.95e+3]
#
#
#
#
# 0:  50%|█████     | 1/2 [00:00<00:00, 17.36it/s, loss=8.83, perplexity=6.84e+3]
#
#
#
#
# 0: 100%|██████████| 2/2 [00:00<00:00, 22.74it/s, loss=8.83, perplexity=6.83e+3]
#
#
#
#
# 0: 3it [00:00, 24.11it/s, loss=8.83, perplexity=6.83e+3]
#
#
#
#
# 0: 4it [00:00, 31.04it/s, loss=8.83, perplexity=6.83e+3]
#
#
#
#
# 0: 4it [00:00, 31.04it/s, loss=7.82, perplexity=2.49e+3]
#
#
#
#
# 0: 5it [00:00, 31.04it/s, loss=7, perplexity=1.1e+3]
#
#
#
#
# 0: 6it [00:00, 31.04it/s, loss=6.55, perplexity=696]
#
#
#
#
# 0: 7it [00:00, 31.04it/s, loss=6.45, perplexity=630]
#
#
#
#
# 0: 8it [00:00, 31.04it/s, loss=6.69, perplexity=806]
#
#
#
#
# 0: 9it [00:00, 33.60it/s, loss=6.69, perplexity=806]
#
#
#
#
# 0: 9it [00:00, 33.60it/s, loss=6.88, perplexity=972]
#
#
#
#
# 0: 10it [00:00, 33.60it/s, loss=7.03, perplexity=1.13e+3]
#
#
#
#
# 0: 11it [00:00, 33.60it/s, loss=7.15, perplexity=1.28e+3]
#
#
#
#
# 0: 12it [00:00, 33.60it/s, loss=6.87, perplexity=966]
#
#
#
#
# 0: 13it [00:00, 33.46it/s, loss=6.87, perplexity=966]
#
#
#
#
# 0: 13it [00:00, 33.46it/s, loss=7, perplexity=1.09e+3]
#
#
#
#
# 0: 14it [00:00, 33.46it/s, loss=6.82, perplexity=914]
#
#
#
#
# 0: 15it [00:00, 33.46it/s, loss=6.65, perplexity=770]
#
#
#
#
# 0: 16it [00:00, 33.46it/s, loss=6.76, perplexity=863]
#
#
#
#
# 0: 17it [00:00, 31.60it/s, loss=6.76, perplexity=863]
#
#
#
#
# 0: 17it [00:00, 31.60it/s, loss=6.66, perplexity=784]
#
#
#
#
# 0: 18it [00:00, 31.60it/s, loss=6.75, perplexity=857]
#
#
#
#
# 0: 19it [00:00, 31.60it/s, loss=6.84, perplexity=930]
#
#
#
#
# 0: 20it [00:00, 31.60it/s, loss=6.91, perplexity=999]
#
#
#
#
# 0: 21it [00:00, 32.26it/s, loss=6.91, perplexity=999]
#
#
#
#
# 0: 21it [00:00, 32.26it/s, loss=6.85, perplexity=940]
#
#
#
#
# 0: 22it [00:00, 32.26it/s, loss=6.89, perplexity=983]
#
#
#
#
# 0: 23it [00:00, 32.26it/s, loss=6.93, perplexity=1.02e+3]
#
#
#
#
# 0: 24it [00:00, 32.26it/s, loss=6.96, perplexity=1.05e+3]
#
#
#
#
# 0: 25it [00:00, 33.62it/s, loss=6.96, perplexity=1.05e+3]
#
#
#
#
# 0: 25it [00:00, 33.62it/s, loss=7.01, perplexity=1.11e+3]
#
#
#
#
# 0: 26it [00:00, 33.62it/s, loss=7.03, perplexity=1.13e+3]
#
#
#
#
# 0: 27it [00:00, 33.62it/s, loss=6.85, perplexity=942]
#
#
#
#
# 0: 28it [00:00, 33.62it/s, loss=6.85, perplexity=940]
#
#
#
#
# 0: 29it [00:00, 34.09it/s, loss=6.85, perplexity=940]
#
#
#
#
# 0: 29it [00:00, 34.09it/s, loss=6.83, perplexity=923]
#
#
#
#
# 0: 30it [00:00, 34.09it/s, loss=6.81, perplexity=904]
#
#
#
#
# 0: 31it [00:00, 34.09it/s, loss=6.81, perplexity=910]
#
#
#
#
# 0: 32it [00:00, 34.09it/s, loss=6.82, perplexity=918]
#
#
#
#
# 0: 33it [00:01, 31.68it/s, loss=6.82, perplexity=918]
#
#
#
#
# 0: 33it [00:01, 31.68it/s, loss=6.84, perplexity=936]
#
#
#
#
# 0: 34it [00:01, 31.68it/s, loss=6.85, perplexity=946]
#
#
#
#
# 0: 35it [00:01, 31.68it/s, loss=6.76, perplexity=861]
#
#
#
#
# 0: 36it [00:01, 31.68it/s, loss=6.76, perplexity=862]
#
#
#
#
# 0: 37it [00:01, 32.01it/s, loss=6.76, perplexity=862]
#
#
#
#
# 0: 37it [00:01, 32.01it/s, loss=6.75, perplexity=856]
#
#
#
#
# 0: 38it [00:01, 32.01it/s, loss=6.72, perplexity=826]
#
#
#
#
# 0: 39it [00:01, 32.01it/s, loss=6.7, perplexity=815]
#
#
#
#
# 0: 40it [00:01, 32.01it/s, loss=6.7, perplexity=814]
#
#
#
#
# 0: 41it [00:01, 32.04it/s, loss=6.7, perplexity=814]
#
#
#
#
# 0: 41it [00:01, 32.04it/s, loss=6.6, perplexity=738]
#
#
#
#
# 0: 42it [00:01, 32.04it/s, loss=6.59, perplexity=728]
#
#
#
#
# 0: 43it [00:01, 32.04it/s, loss=6.58, perplexity=722]
#
#
#
#
# 0: 44it [00:01, 32.04it/s, loss=6.56, perplexity=709]
#
#
#
#
# 0: 45it [00:01, 31.75it/s, loss=6.56, perplexity=709]
#
#
#
#
# 0: 45it [00:01, 31.75it/s, loss=6.53, perplexity=685]
#
#
#
#
# 0: 46it [00:01, 31.75it/s, loss=6.5, perplexity=663]
#
#
#
#
# 0: 47it [00:01, 31.75it/s, loss=6.39, perplexity=599]
#
#
#
#
# 0: 48it [00:01, 31.75it/s, loss=6.37, perplexity=586]
#
#
#
#
# 0: 49it [00:01, 31.75it/s, loss=6.32, perplexity=556]
#
#
#
#
# 0: 50it [00:01, 34.55it/s, loss=6.32, perplexity=556]
#
#
#
#
# 0: 50it [00:01, 34.55it/s, loss=6.32, perplexity=555]
#
#
#
#
# 0: 51it [00:01, 34.55it/s, loss=6.3, perplexity=544]
#
#
#
#
# 0: 52it [00:01, 34.55it/s, loss=6.3, perplexity=547]
#
#
#
#
# 0: 53it [00:01, 34.55it/s, loss=6.28, perplexity=531]
#
#
#
#
# 0: 54it [00:01, 32.96it/s, loss=6.28, perplexity=531]
#
#
#
#
# 0: 54it [00:01, 32.96it/s, loss=6.22, perplexity=500]
#
#
#
#
# 0: 55it [00:01, 32.96it/s, loss=6.21, perplexity=500]
#
#
#
#
# 0: 56it [00:01, 32.96it/s, loss=6.2, perplexity=495]
#
#
#
#
# 0: 57it [00:01, 32.96it/s, loss=6.15, perplexity=470]
#
#
#
#
# 0: 58it [00:01, 32.68it/s, loss=6.15, perplexity=470]
#
#
#
#
# 0: 58it [00:01, 32.68it/s, loss=6.14, perplexity=463]
#
#
#
#
# 0: 59it [00:01, 32.68it/s, loss=6.12, perplexity=455]
#
#
#
#
# 0: 60it [00:01, 32.68it/s, loss=6.09, perplexity=442]
#
#
#
#
# 0: 61it [00:01, 32.68it/s, loss=6.1, perplexity=447]
#
#
#
#
# 0: 62it [00:01, 32.57it/s, loss=6.1, perplexity=447]
#
#
#
#
# 0: 62it [00:01, 32.57it/s, loss=6.05, perplexity=426]
#
#
#
#
# 0: 63it [00:01, 32.57it/s, loss=6.04, perplexity=419]
#
#
#
#
# 0: 64it [00:01, 32.57it/s, loss=6.03, perplexity=415]
#
#
#
#
# 0: 65it [00:01, 32.57it/s, loss=5.99, perplexity=398]
#
#
#
#
# 0: 66it [00:01, 33.25it/s, loss=5.99, perplexity=398]
#
#
#
#
# 0: 66it [00:02, 33.25it/s, loss=5.98, perplexity=397]
#
#
#
#
# 0: 67it [00:02, 33.25it/s, loss=5.96, perplexity=389]
#
#
#
#
# 0: 68it [00:02, 33.25it/s, loss=5.96, perplexity=387]
#
#
#
#
# 0: 69it [00:02, 33.25it/s, loss=5.95, perplexity=382]
#
#
#
#
# 0: 70it [00:02, 32.82it/s, loss=5.95, perplexity=382]
#
#
#
#
# 0: 70it [00:02, 32.82it/s, loss=5.91, perplexity=369]
#
#
#
#
# 0: 71it [00:02, 32.82it/s, loss=5.88, perplexity=359]
#
#
#
#
# 0: 72it [00:02, 32.82it/s, loss=5.89, perplexity=361]
#
#
#
#
# 0: 73it [00:02, 32.82it/s, loss=5.89, perplexity=362]
#
#
#
#
# 0: 74it [00:02, 31.86it/s, loss=5.89, perplexity=362]
#
#
#
#
# 0: 74it [00:02, 31.86it/s, loss=5.87, perplexity=356]
#
#
#
#
# 0: 75it [00:02, 31.86it/s, loss=5.84, perplexity=345]
#
#
#
#
# 0: 76it [00:02, 31.86it/s, loss=5.83, perplexity=339]
#
#
#
#
# 0: 77it [00:02, 31.86it/s, loss=5.79, perplexity=326]
#
#
#
#
# 0: 78it [00:02, 33.86it/s, loss=5.79, perplexity=326]
#
#
#
#
# 0: 78it [00:02, 33.86it/s, loss=5.76, perplexity=319]
#
#
#
#
# 0: 79it [00:02, 33.86it/s, loss=5.75, perplexity=315]
#
#
#
#
# 0: 80it [00:02, 33.86it/s, loss=5.72, perplexity=306]
#
#
#
#
# 0: 81it [00:02, 33.86it/s, loss=5.72, perplexity=305]
#
#
#
#
# 0: 82it [00:02, 32.32it/s, loss=5.72, perplexity=305]
#
#
#
#
# 0: 82it [00:02, 32.32it/s, loss=5.72, perplexity=306]
#
#
#
#
# 0: 83it [00:02, 32.32it/s, loss=5.71, perplexity=302]
#
#
#
#
# 0: 84it [00:02, 32.32it/s, loss=5.7, perplexity=298]
#
#
#
#
# 0: 85it [00:02, 32.32it/s, loss=5.68, perplexity=292]
#
#
#
#
# 0: 86it [00:02, 33.82it/s, loss=5.68, perplexity=292]
#
#
#
#
# 0: 86it [00:02, 33.82it/s, loss=5.67, perplexity=289]
#
#
#
#
# 0: 87it [00:02, 33.82it/s, loss=5.65, perplexity=284]
#
#
#
#
# 0: 88it [00:02, 33.82it/s, loss=5.64, perplexity=281]
#
#
#
#
# 0: 89it [00:02, 33.82it/s, loss=5.63, perplexity=279]
#
#
#
#
# 0: 90it [00:02, 32.62it/s, loss=5.63, perplexity=279]
#
#
#
#
# 0: 90it [00:02, 32.62it/s, loss=5.62, perplexity=277]
#
#
#
#
# 0: 91it [00:02, 32.62it/s, loss=5.6, perplexity=271]
#
#
#
#
# 0: 92it [00:02, 32.62it/s, loss=5.59, perplexity=268]
#
#
#
#
# 0: 93it [00:02, 32.62it/s, loss=5.58, perplexity=265]
#
#
#
#
# 0: 94it [00:02, 33.71it/s, loss=5.58, perplexity=265]
#
#
#
#
# 0: 94it [00:02, 33.71it/s, loss=5.56, perplexity=259]
#
#
#
#
# 0: 95it [00:02, 33.71it/s, loss=5.53, perplexity=253]
#
#
#
#
# 0: 96it [00:02, 33.71it/s, loss=5.53, perplexity=252]
#
#
#
#
# 0: 97it [00:02, 33.71it/s, loss=5.53, perplexity=251]
#
#
#
#
# 0: 98it [00:02, 32.75it/s, loss=5.53, perplexity=251]
#
#
#
#
# 0: 98it [00:03, 32.75it/s, loss=5.54, perplexity=254]
#
#
#
#
# 0: 99it [00:03, 32.75it/s, loss=5.53, perplexity=252]
#
#
#
#
# 0: 100it [00:03, 32.75it/s, loss=5.51, perplexity=248]
#
#
#
#
# 0: 101it [00:03, 32.75it/s, loss=5.52, perplexity=248]
#
#
#
#
# 0: 102it [00:03, 31.22it/s, loss=5.52, perplexity=248]
#
#
#
#
# 0: 102it [00:03, 31.22it/s, loss=5.5, perplexity=246]
#
#
#
#
# 0: 103it [00:03, 31.22it/s, loss=5.51, perplexity=246]
#
#
#
#
# 0: 104it [00:03, 31.22it/s, loss=5.51, perplexity=247]
#
#
#
#
# 0: 105it [00:03, 31.22it/s, loss=5.5, perplexity=246]
#
#
#
#
# 0: 106it [00:03, 29.99it/s, loss=5.5, perplexity=246]
#
#
#
#
# 0: 106it [00:03, 29.99it/s, loss=5.51, perplexity=246]
#
#
#
#
# 0: 107it [00:03, 29.99it/s, loss=5.5, perplexity=244]
#
#
#
#
# 0: 108it [00:03, 29.99it/s, loss=5.49, perplexity=242]
#
#
#
#
# 0: 109it [00:03, 29.99it/s, loss=5.47, perplexity=237]
#
#
#
#
# 0: 110it [00:03, 30.52it/s, loss=5.47, perplexity=237]
#
#
#
#
# 0: 110it [00:03, 30.52it/s, loss=5.45, perplexity=233]
#
#
#
#
# 0: 111it [00:03, 30.52it/s, loss=5.43, perplexity=227]
#
#
#
#
# 0: 112it [00:03, 30.52it/s, loss=5.42, perplexity=226]
#
#
#
#
# 0: 113it [00:03, 30.52it/s, loss=5.43, perplexity=228]
#
#
#
#
# 0: 114it [00:03, 30.52it/s, loss=5.41, perplexity=224]
#
#
#
#
# 0: 115it [00:03, 32.83it/s, loss=5.41, perplexity=224]
#
#
#
#
# 0: 115it [00:03, 32.83it/s, loss=5.42, perplexity=225]
#
#
#
#
# 0: 116it [00:03, 32.83it/s, loss=5.42, perplexity=225]
#
#
#
#
# 0: 117it [00:03, 32.83it/s, loss=5.41, perplexity=224]
#
#
#
#
# 0: 118it [00:03, 32.83it/s, loss=5.4, perplexity=222]
#
#
#
#
# 0: 119it [00:03, 32.37it/s, loss=5.4, perplexity=222]
#
#
#
#
# 0: 119it [00:03, 32.37it/s, loss=5.39, perplexity=219]
#
#
#
#
# 0: 120it [00:03, 32.37it/s, loss=5.4, perplexity=221]
#
#
#
#
# 0: 121it [00:03, 32.37it/s, loss=5.38, perplexity=217]
#
#
#
#
# 0: 122it [00:03, 32.37it/s, loss=5.38, perplexity=217]
#
#
#
#
# 0: 123it [00:03, 32.33it/s, loss=5.38, perplexity=217]
#
#
#
#
# 0: 123it [00:03, 32.33it/s, loss=5.37, perplexity=216]
#
#
#
#
# 0: 124it [00:03, 32.33it/s, loss=5.37, perplexity=215]
#
#
#
#
# 0: 125it [00:03, 32.33it/s, loss=5.36, perplexity=214]
#
#
#
#
# 0: 126it [00:03, 32.33it/s, loss=5.36, perplexity=212]
#
#
#
#
# 0: 127it [00:03, 32.47it/s, loss=5.36, perplexity=212]
#
#
#
#
# 0: 127it [00:03, 32.47it/s, loss=5.35, perplexity=210]
#
#
#
#
# 0: 128it [00:03, 32.47it/s, loss=5.34, perplexity=209]
#
#
#
#
# 0: 129it [00:03, 32.47it/s, loss=5.34, perplexity=209]
#
#
#
#
# 0: 130it [00:03, 32.47it/s, loss=5.33, perplexity=205]
#
#
#
#
# 0: 131it [00:03, 33.70it/s, loss=5.33, perplexity=205]
#
#
#
#
# 0: 131it [00:04, 33.70it/s, loss=5.32, perplexity=204]
#
#
#
#
# 0: 132it [00:04, 33.70it/s, loss=5.31, perplexity=202]
#
#
#
#
# 0: 133it [00:04, 33.70it/s, loss=5.31, perplexity=202]
#
#
#
#
# 0: 134it [00:04, 33.70it/s, loss=5.3, perplexity=201]
#
#
#
#
# 0: 135it [00:04, 32.71it/s, loss=5.3, perplexity=201]
#
#
#
#
# 0: 135it [00:04, 32.71it/s, loss=5.3, perplexity=201]
#
#
#
#
# 0: 136it [00:04, 32.71it/s, loss=5.29, perplexity=199]
#
#
#
#
# 0: 137it [00:04, 32.71it/s, loss=5.29, perplexity=199]
#
#
#
#
# 0: 138it [00:04, 32.71it/s, loss=5.29, perplexity=198]
#
#
#
#
# 0: 139it [00:04, 33.14it/s, loss=5.29, perplexity=198]
#
#
#
#
# 0: 139it [00:04, 33.14it/s, loss=5.29, perplexity=199]
#
#
#
#
# 0: 140it [00:04, 33.14it/s, loss=5.28, perplexity=197]
#
#
#
#
# 0: 141it [00:04, 33.14it/s, loss=5.28, perplexity=196]
#
#
#
#
# 0: 142it [00:04, 33.14it/s, loss=5.27, perplexity=194]
#
#
#
#
# 0: 143it [00:04, 30.02it/s, loss=5.27, perplexity=194]
#
#
#
#
# 0: 143it [00:04, 30.02it/s, loss=5.26, perplexity=193]
#
#
#
#
# 0: 144it [00:04, 30.02it/s, loss=5.27, perplexity=195]
#
#
#
#
# 0: 145it [00:04, 30.02it/s, loss=5.28, perplexity=195]
#
#
#
#
# 0: 146it [00:04, 30.02it/s, loss=5.26, perplexity=193]
#
#
#
#
# 0: 147it [00:04, 31.29it/s, loss=5.26, perplexity=193]
#
#
#
#
# 0: 147it [00:04, 31.29it/s, loss=5.26, perplexity=192]
#
#
#
#
# 0: 148it [00:04, 31.29it/s, loss=5.25, perplexity=190]
#
#
#
#
# 0: 149it [00:04, 31.29it/s, loss=5.23, perplexity=187]
#
#
#
#
# 0: 150it [00:04, 31.29it/s, loss=5.22, perplexity=185]
#
#
#
#
# 0: 151it [00:04, 32.35it/s, loss=5.22, perplexity=185]
#
#
#
#
# 0: 151it [00:04, 32.35it/s, loss=5.21, perplexity=183]
#
#
#
#
# 0: 152it [00:04, 32.35it/s, loss=5.21, perplexity=183]
#
#
#
#
# 0: 153it [00:04, 32.35it/s, loss=5.19, perplexity=180]
#
#
#
#
# 0: 154it [00:04, 32.35it/s, loss=5.18, perplexity=177]
#
#
#
#
# 0: 155it [00:04, 32.62it/s, loss=5.18, perplexity=177]
#
#
#
#
# 0: 155it [00:04, 32.62it/s, loss=5.17, perplexity=176]
#
#
#
#
# 0: 156it [00:04, 32.62it/s, loss=5.17, perplexity=176]
#
#
#
#
# 0: 157it [00:04, 32.62it/s, loss=5.18, perplexity=177]
#
#
#
#
# 0: 158it [00:04, 32.62it/s, loss=5.17, perplexity=176]
#
#
#
#
# 0: 159it [00:04, 31.68it/s, loss=5.17, perplexity=176]
#
#
#
#
# 0: 159it [00:04, 31.68it/s, loss=5.16, perplexity=174]
#
#
#
#
# 0: 160it [00:04, 31.68it/s, loss=5.14, perplexity=171]
#
#
#
#
# 0: 161it [00:04, 31.68it/s, loss=5.13, perplexity=169]
#
#
#
#
# 0: 162it [00:04, 31.68it/s, loss=5.13, perplexity=170]
#
#
#
#
# 0: 163it [00:05, 31.70it/s, loss=5.13, perplexity=170]
#
#
#
#
# 0: 163it [00:05, 31.70it/s, loss=5.13, perplexity=169]
#
#
#
#
# 0: 164it [00:05, 31.70it/s, loss=5.14, perplexity=171]
#
#
#
#
# 0: 165it [00:05, 31.70it/s, loss=5.13, perplexity=169]
#
#
#
#
# 0: 166it [00:05, 31.70it/s, loss=5.12, perplexity=167]
#
#
#
#
# 0: 167it [00:05, 31.05it/s, loss=5.12, perplexity=167]
#
#
#
#
# 0: 167it [00:05, 31.05it/s, loss=5.12, perplexity=167]
#
#
#
#
# 0: 168it [00:05, 31.05it/s, loss=5.11, perplexity=165]
#
#
#
#
# 0: 169it [00:05, 31.05it/s, loss=5.11, perplexity=165]
#
#
#
#
# 0: 170it [00:05, 31.05it/s, loss=5.1, perplexity=164]
#
#
#
#
# 0: 171it [00:05, 29.48it/s, loss=5.1, perplexity=164]
#
#
#
#
# 0: 171it [00:05, 29.48it/s, loss=5.1, perplexity=164]
#
#
#
#
# 0: 172it [00:05, 29.48it/s, loss=5.1, perplexity=164]
#
#
#
#
# 0: 173it [00:05, 29.48it/s, loss=5.11, perplexity=165]
#
#
#
#
# 0: 174it [00:05, 29.02it/s, loss=5.11, perplexity=165]
#
#
#
#
# 0: 174it [00:05, 29.02it/s, loss=5.11, perplexity=165]
#
#
#
#
# 0: 175it [00:05, 29.02it/s, loss=5.11, perplexity=166]
#
#
#
#
# 0: 176it [00:05, 29.02it/s, loss=5.1, perplexity=165]
#
#
#
#
# 0: 177it [00:05, 29.02it/s, loss=5.1, perplexity=163]
#
#
#
#
# 0: 178it [00:05, 29.56it/s, loss=5.1, perplexity=163]
#
#
#
#
# 0: 178it [00:05, 29.56it/s, loss=5.09, perplexity=162]
#
#
#
#
# 0: 179it [00:05, 29.56it/s, loss=5.09, perplexity=162]
#
#
#
#
# 0: 180it [00:05, 29.56it/s, loss=5.09, perplexity=163]
#
#
#
#
# 0: 181it [00:05, 29.60it/s, loss=5.09, perplexity=163]
#
#
#
#
# 0: 181it [00:05, 29.60it/s, loss=5.09, perplexity=162]
#
#
#
#
# 0: 182it [00:05, 29.60it/s, loss=5.09, perplexity=162]
#
#
#
#
# 0: 183it [00:05, 29.60it/s, loss=5.08, perplexity=161]
#
#
#
#
# 0: 184it [00:05, 27.79it/s, loss=5.08, perplexity=161]
#
#
#
#
# 0: 184it [00:05, 27.79it/s, loss=5.07, perplexity=160]
#
#
#
#
# 0: 185it [00:05, 27.79it/s, loss=5.07, perplexity=159]
#
#
#
#
# 0: 186it [00:05, 27.79it/s, loss=5.07, perplexity=159]
#
#
#
#
# 0: 187it [00:05, 27.54it/s, loss=5.07, perplexity=159]
#
#
#
#
# 0: 187it [00:05, 27.54it/s, loss=5.08, perplexity=160]
#
#
#
#
# 0: 188it [00:05, 27.54it/s, loss=5.07, perplexity=158]
#
#
#
#
# 0: 189it [00:05, 27.54it/s, loss=5.06, perplexity=157]
#
#
#
#
# 0: 190it [00:05, 27.50it/s, loss=5.06, perplexity=157]
#
#
#
#
# 0: 190it [00:06, 27.50it/s, loss=5.06, perplexity=157]
#
#
#
#
# 0: 191it [00:06, 27.50it/s, loss=5.06, perplexity=157]
#
#
#
#
# 0: 192it [00:06, 27.50it/s, loss=5.06, perplexity=158]
#
#
#
#
# 0: 193it [00:06, 27.50it/s, loss=5.06, perplexity=158]
#
#
#
#
# 0: 194it [00:06, 27.89it/s, loss=5.06, perplexity=158]
#
#
#
#
# 0: 194it [00:06, 27.89it/s, loss=5.06, perplexity=158]
#
#
#
#
# 0: 195it [00:06, 27.89it/s, loss=5.06, perplexity=158]
#
#
#
#
# 0: 196it [00:06, 27.89it/s, loss=5.06, perplexity=158]
#
#
#
#
# 0: 197it [00:06, 28.41it/s, loss=5.06, perplexity=158]
#
#
#
#
# 0: 197it [00:06, 28.41it/s, loss=5.06, perplexity=157]
#
#
#
#
# 0: 198it [00:06, 28.41it/s, loss=5.05, perplexity=157]
#
#
#
#
# 0: 199it [00:06, 28.41it/s, loss=5.05, perplexity=156]
#
#
#
#
# 0: 200it [00:06, 28.41it/s, loss=5.04, perplexity=155]
#
#
#
#
# 0: 201it [00:06, 29.22it/s, loss=5.04, perplexity=155]
#
#
#
#
# 0: 201it [00:06, 29.22it/s, loss=5.03, perplexity=153]
#
#
#
#
# 0: 202it [00:06, 29.22it/s, loss=5.03, perplexity=152]
#
#
#
#
# 0: 203it [00:06, 29.22it/s, loss=5.02, perplexity=151]
#
#
#
#
# 0: 204it [00:06, 28.97it/s, loss=5.02, perplexity=151]
#
#
#
#
# 0: 204it [00:06, 28.97it/s, loss=5.01, perplexity=149]
#
#
#
#
# 0: 205it [00:06, 28.97it/s, loss=5, perplexity=149]
#
#
#
#
# 0: 206it [00:06, 28.97it/s, loss=4.99, perplexity=148]
#
#
#
#
# 0: 207it [00:06, 28.97it/s, loss=5, perplexity=148]
#
#
#
#
# 0: 208it [00:06, 29.57it/s, loss=5, perplexity=148]
#
#
#
#
# 0: 208it [00:06, 29.57it/s, loss=4.99, perplexity=147]
#
#
#
#
# 0: 209it [00:06, 29.57it/s, loss=4.99, perplexity=147]
#
#
#
#
# 0: 210it [00:06, 29.57it/s, loss=4.98, perplexity=145]
#
#
#
#
# 0: 211it [00:06, 29.57it/s, loss=4.97, perplexity=145]
#
#
#
#
# 0: 212it [00:06, 30.08it/s, loss=4.97, perplexity=145]
#
#
#
#
# 0: 212it [00:06, 30.08it/s, loss=4.97, perplexity=145]
#
#
#
#
# 0: 213it [00:06, 30.08it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 214it [00:06, 30.08it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 215it [00:06, 30.08it/s, loss=4.96, perplexity=143]
#
#
#
#
# 0: 216it [00:06, 29.87it/s, loss=4.96, perplexity=143]
#
#
#
#
# 0: 216it [00:06, 29.87it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 217it [00:06, 29.87it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 218it [00:06, 29.87it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 219it [00:06, 27.95it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 219it [00:07, 27.95it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 220it [00:07, 27.95it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 221it [00:07, 27.95it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 222it [00:07, 26.80it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 222it [00:07, 26.80it/s, loss=4.96, perplexity=143]
#
#
#
#
# 0: 223it [00:07, 26.80it/s, loss=4.96, perplexity=142]
#
#
#
#
# 0: 224it [00:07, 26.80it/s, loss=4.96, perplexity=142]
#
#
#
#
# 0: 225it [00:07, 26.80it/s, loss=4.95, perplexity=142]
#
#
#
#
# 0: 226it [00:07, 28.31it/s, loss=4.95, perplexity=142]
#
#
#
#
# 0: 226it [00:07, 28.31it/s, loss=4.95, perplexity=141]
#
#
#
#
# 0: 227it [00:07, 28.31it/s, loss=4.94, perplexity=140]
#
#
#
#
# 0: 228it [00:07, 28.31it/s, loss=4.94, perplexity=139]
#
#
#
#
# 0: 229it [00:07, 28.31it/s, loss=4.93, perplexity=138]
#
#
#
#
# 0: 230it [00:07, 29.46it/s, loss=4.93, perplexity=138]
#
#
#
#
# 0: 230it [00:07, 29.46it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 231it [00:07, 29.46it/s, loss=4.94, perplexity=140]
#
#
#
#
# 0: 232it [00:07, 29.46it/s, loss=4.94, perplexity=139]
#
#
#
#
# 0: 233it [00:07, 29.25it/s, loss=4.94, perplexity=139]
#
#
#
#
# 0: 233it [00:07, 29.25it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 234it [00:07, 29.25it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 235it [00:07, 29.25it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 236it [00:07, 28.62it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 236it [00:07, 28.62it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 237it [00:07, 28.62it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 238it [00:07, 28.62it/s, loss=4.93, perplexity=138]
#
#
#
#
# 0: 239it [00:07, 28.62it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 240it [00:07, 30.22it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 240it [00:07, 30.22it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 241it [00:07, 30.22it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 242it [00:07, 30.22it/s, loss=4.94, perplexity=139]
#
#
#
#
# 0: 243it [00:07, 30.22it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 244it [00:07, 30.06it/s, loss=4.93, perplexity=139]
#
#
#
#
# 0: 244it [00:07, 30.06it/s, loss=4.94, perplexity=139]
#
#
#
#
# 0: 245it [00:07, 30.06it/s, loss=4.94, perplexity=140]
#
#
#
#
# 0: 246it [00:07, 30.06it/s, loss=4.94, perplexity=140]
#
#
#
#
# 0: 247it [00:07, 30.06it/s, loss=4.94, perplexity=139]
#
#
#
#
# 0: 248it [00:07, 28.13it/s, loss=4.94, perplexity=139]
#
#
#
#
# 0: 248it [00:07, 28.13it/s, loss=4.94, perplexity=140]
#
#
#
#
# 0: 249it [00:08, 28.13it/s, loss=4.95, perplexity=141]
#
#
#
#
# 0: 250it [00:08, 28.13it/s, loss=4.95, perplexity=141]
#
#
#
#
# 0: 251it [00:08, 28.02it/s, loss=4.95, perplexity=141]
#
#
#
#
# 0: 251it [00:08, 28.02it/s, loss=4.95, perplexity=141]
#
#
#
#
# 0: 252it [00:08, 28.02it/s, loss=4.95, perplexity=141]
#
#
#
#
# 0: 253it [00:08, 28.02it/s, loss=4.95, perplexity=141]
#
#
#
#
# 0: 254it [00:08, 28.02it/s, loss=4.95, perplexity=141]
#
#
#
#
# 0: 255it [00:08, 27.42it/s, loss=4.95, perplexity=141]
#
#
#
#
# 0: 255it [00:08, 27.42it/s, loss=4.96, perplexity=143]
#
#
#
#
# 0: 256it [00:08, 27.42it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 257it [00:08, 27.42it/s, loss=4.97, perplexity=144]
#
#
#
#
# 0: 258it [00:08, 28.08it/s, loss=4.97, perplexity=144]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-217b44b147f8> in <module>()
#       3 attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)
#       4
# ----> 5 trainIters(encoder1, attn_decoder1, 2)
#
# <ipython-input-60-992e6f7b9427> in trainIters(encoder, decoder, epochs, print_every, plot_every, learning_rate)
#      24
#      25           loss = train(input_tensor, target_tensor, encoder,
# ---> 26                       decoder, encoder_optimizer, decoder_optimizer, criterion)
#      27           loss_total += loss
#      28           plot_loss_total += loss
#
# <ipython-input-27-a1eae311b0e0> in train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length)
#      47                 break
#      48
# ---> 49     loss.backward()
#      50
#      51     encoder_optimizer.step()
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:

# %%
phrase, tenz = evaluate(encoder1, attn_decoder1, "I want to kill")
phrase
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-175-bcdd859b05bf> in <module>()
# ----> 1 phrase, tenz = evaluate(encoder1, attn_decoder1, "I want to kill")
#       2 phrase
#
# <ipython-input-166-881d27a56888> in evaluate(encoder, decoder, sentence, max_length)
#       1 def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
#       2     with torch.no_grad():
# ----> 3         input_tensor = tensorFromSentence(input_lang, sentence)
#       4         input_length = input_tensor.size()[0]
#       5         encoder_hidden = encoder.initHidden()
#
# <ipython-input-165-bb69e91c7422> in tensorFromSentence(lang, sentence)
#       4
#       5 def tensorFromSentence(lang, sentence):
# ----> 6     indexes = indexesFromSentence(lang, sentence)
#       7     indexes.append(EOS_token)
#       8     return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)
#
# <ipython-input-165-bb69e91c7422> in indexesFromSentence(lang, sentence)
#       1 def indexesFromSentence(lang, sentence):
# ----> 2     return [lang.word2index[word] for word in sentence.split(' ')]
#       3
#       4
#       5 def tensorFromSentence(lang, sentence):
#
# <ipython-input-165-bb69e91c7422> in <listcomp>(.0)
#       1 def indexesFromSentence(lang, sentence):
# ----> 2     return [lang.word2index[word] for word in sentence.split(' ')]
#       3
#       4
#       5 def tensorFromSentence(lang, sentence):
#
# KeyError: 'I'

# %%
evaluateRandomly(encoder1, attn_decoder1)

# %%
def showAttention(input_sentence, output_words, attentions):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()


def evaluateAndShow(input_sentence):
    output_words, attentions = evaluate(
        encoder1, attn_decoder1, input_sentence)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))



evaluateAndShow("I want to eat")
evaluateAndShow("I want to kill")
evaluateAndShow("I want to drink")
evaluateAndShow("I kill you")
